# %%
# Dependencies and Setup
import pandas as pd

# File to Load 
vaccination_data= "Raw Data/Polio Vaccination.csv"
cases_data = "Raw Data/Polio Cases.csv"

# Read Vaccination and Case Data File and store into Pandas Data Frames
vaccination = pd.read_csv(vaccination_data)
cases = pd.read_csv(cases_data)

# %%
# Clean data sets and create dataframes
vaccination_df = pd.DataFrame(vaccination)
vaccination_df


# Remove uneccessary columns
vaccination_df.drop(['Polio (Pol3) immunization coverage among 1-year-olds (%)',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).8',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).9',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).10',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).11',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).12',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).13',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).14',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).15',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).16',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).17',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).18',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).19',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).20',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).21',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).22',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).23',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).24',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).25',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).26',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).27',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).28',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).29',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).30',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).31',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).32',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).33',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).34',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).35',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).36',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).37',
       'Polio (Pol3) immunization coverage among 1-year-olds (%).38'], axis=1, inplace=True)

# Replace header
new_header = vaccination_df.iloc[0] # Grab the first row for the header
vaccination_df = vaccination_df[1:] # Take the data less the header row
vaccination_df.columns = new_header

# Remove id and set index as Country
vaccination_df = vaccination_df.set_index(["Country"])

# Display dataframe
vaccination_df
# Out:
# 0                                                   2017  2016  2015  2014  \
# Country
# Afghanistan                                           73    73    67    58
# Albania                                               99    98    99    98
# Algeria                                               91    91    95    95
# Andorra                                               99    98    97    97
# Angola                                                47    53    57    55
# Antigua and Barbuda                                   94    87    86    96
# Argentina                                             84    87    93    92
# Armenia                                               96    96    96    95
# Australia                                             95    94    93    92
# Austria                                               90    87    93    98
# Azerbaijan                                            97    98    98    97
# ...

# %%
vaccination_df = pd.DataFrame(vaccination_df.unstack().copy(), columns=['Polio Vaccinated Rate'])
vaccination_df.reset_index(drop=False, inplace=True)
vaccination_df.rename(columns={0:'Year'}, inplace=True)
vaccination_df.set_index(['Country','Year'])
# Out:
#                                                          Polio Vaccinated Rate
# Country                                            Year
# Afghanistan                                        2017                     73
# Albania                                            2017                     99
# Algeria                                            2017                     91
# Andorra                                            2017                     99
# Angola                                             2017                     47
# Antigua and Barbuda                                2017                     94
# Argentina                                          2017                     84
# Armenia                                            2017                     96
# Australia                                          2017                     95
# Austria                                            2017                     90
# ...

# %%
cases_df = pd.DataFrame(cases)

# Replace NaN with a value of zero
cases_df.fillna(0)

# Remove uneccessary columns
cases_df.drop(['Code'], axis=1, inplace=True)

# Delete years 2018 and 2019 to make all datasets years consistent
cases_df = cases_df[cases_df.Year >= 2011]

# Rename column titles
# vaccination_df.rename(columns={'LOCATION':'Country', 'TIME':'Year', 'Value':'Vaccinated Rate'}, inplace=True)
cases_df.rename(columns={'Estimated number of paralytic polio cases using reported number of cases after polio free certification (WHO, 2018 and Tebbens et al., 2011)':'Total Polio Cases', 'Entity':'Country'}, inplace=True)

# Remove id and set index as Country and Year
cases_df = cases_df.set_index(["Country", "Year"])

# Display all rows in the dataframe
pd.set_option('display.max_rows', 1031)

# Display dataframe
cases_df
# Out:
#                                    Total Polio Cases
# Country                      Year
# Afghanistan                  2011          89.910004
#                              2012          51.060001
#                              2013          18.870001
#                              2014          31.080000
#                              2015          22.200001
#                              2016          14.430000
# Africa                       2011         407.450012
#                              2012         182.300003
#                              2013          98.270004
#                              2014          54.959999
#                              2015          18.110001
#                              2016           5.550000
# Albania                      2011           0.000000
#                              2012           0.000000
#                              2013           0.000000
#                              2014           0.000000
# ...
